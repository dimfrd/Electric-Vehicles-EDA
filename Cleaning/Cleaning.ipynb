# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
evdata = pd.read_csv(r'C:\Users\El\Desktop\Electric-Vehicles-EDA\Data\electric_vehicle_population_data.csv.zip')

# %%
evdata.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year   Make  \
# 0  WAUTPBFF4H      King  Seattle    WA      98126.0        2017   AUDI
# 1  WAUUPBFF2J  Thurston  Olympia    WA      98502.0        2018   AUDI
# 2  5YJSA1E22H  Thurston    Lacey    WA      98516.0        2017  TESLA
# 3  1C4JJXP62M  Thurston   Tenino    WA      98589.0        2021   JEEP
# 4  5YJ3E1EC9L    Yakima   Yakima    WA      98902.0        2020  TESLA
#
#       Model                   Electric Vehicle Type  \
# 0        A3  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        A3  Plug-in Hybrid Electric Vehicle (PHEV)
# 2   MODEL S          Battery Electric Vehicle (BEV)
# 3  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 4   MODEL 3          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0             Not eligible due to low battery range              16
# 1             Not eligible due to low battery range              16
# ...

# %%
evdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181458 entries, 0 to 181457
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         181458 non-null  object
#  1   County                                             181455 non-null  object
#  2   City                                               181455 non-null  object
#  3   State                                              181458 non-null  object
#  4   Postal Code                                        181455 non-null  float64
#  5   Model Year                                         181458 non-null  int64
#  6   Make                                               181458 non-null  object
#  7   Model                                              181458 non-null  object
# ...

# %%
evdata.isna().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 398
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       3
# ...

# %%
evdata[evdata['County'].isna()]
# Out:
#         VIN (1-10) County City State  Postal Code  Model Year   Make    Model  \
# 91      5YJSA1E21J    NaN  NaN    AE          NaN        2018  TESLA  MODEL S
# 136484  5YJXCAE24H    NaN  NaN    BC          NaN        2017  TESLA  MODEL X
# 163689  5YJ3E1EA5K    NaN  NaN    BC          NaN        2019  TESLA  MODEL 3
#
#                  Electric Vehicle Type  \
# 91      Battery Electric Vehicle (BEV)
# 136484  Battery Electric Vehicle (BEV)
# 163689  Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 91               Clean Alternative Fuel Vehicle Eligible             249
# 136484           Clean Alternative Fuel Vehicle Eligible             200
# 163689           Clean Alternative Fuel Vehicle Eligible             220
#
#         Base MSRP  Legislative District  DOL Vehicle ID Vehicle Location  \
# 91              0                   NaN       220643132              NaN
# ...

# %%
evdata[evdata['County'].notna()].isna().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  0
# Postal Code                                            0
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 395
# DOL Vehicle ID                                         0
# Vehicle Location                                       5
# Electric Utility                                       0
# ...

# %%
evdata = evdata[evdata['County'].notna()]

# %%
evdata['Postal Code'] = evdata['Postal Code'].astype(int)
evdata['2020 Census Tract'] = evdata['2020 Census Tract'].astype(int)
# Out:
# C:\Users\El\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)

# %%
#evdata.info()

# %%
#exporting cleaned df
evdata.to_csv(r'C:\Users\El\Desktop\Electric-Vehicles-EDA\Data\evcleaned.csv')
